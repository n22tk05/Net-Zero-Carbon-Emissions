# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/master_dataset_clean.csv')
not_cols = ['country_code', 'country', 'year', 'income_group']
feature_cols = [c for c in df.columns if c not in not_cols]
feature_cols
# Out:
# ['co2_per_capita',
#  'co2',
#  'BANK',
#  'ATM',
#  'DEP',
#  'LOAN',
#  'FT_Mobile',
#  'FT_Broadband',
#  'FT_Internet',
#  'LCE',
#  'URB',
#  'FDI',
#  'GDP',
#  'NTR',
#  'PO',
#  'TO',
#  'IND',
#  'INF',
#  'PS',
#  'ED',
#  'ef_per_capita']

# %%
log_df = df.copy()
log_df[feature_cols] = np.log(log_df[feature_cols])
log_df
# Out:
# c:\Users\ADMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\ADMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
#      country_code  country  year  co2_per_capita       co2      BANK  \
# 0             AND  Andorra  2010        1.856298 -0.659712  3.284505
# 1             AND  Andorra  2011        1.842294 -0.711311  3.326800
# 2             AND  Andorra  2012        1.846879 -0.719491  3.333872
# 3             AND  Andorra  2013        1.845616 -0.742337  3.342722
# 4             AND  Andorra  2014        1.834020 -0.772190  3.365346
# ...           ...      ...   ...             ...       ...       ...
# 2185          ZMB   Zambia  2020       -0.646264  2.301685  1.101683
# ...
